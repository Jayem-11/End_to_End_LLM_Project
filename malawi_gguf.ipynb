# %%
# %%capture
# !git clone https://github.com/ggerganov/llama.cpp.git
# !pip install -r llama.cpp/requirements.txt

# %%
from huggingface_hub import login
secret_value ="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"
login(token=secret_value)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import snapshot_download
model_id="Jayem-11/Llama-2-13b_malawi_merged"
snapshot_download(repo_id=model_id, local_dir="Llama-2-13b_malawi_merged",
                  local_dir_use_symlinks=False, revision="main")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/29.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# ...

# %%
# !python llama.cpp/convert.py Llama-2-13b_malawi_merged --outfile Llama-2-13b_malawi_merged.gguf --outtype  q8_0
# Out:
# Loading model file Llama-2-13b_malawi_merged/model-00001-of-00006.safetensors
# Loading model file Llama-2-13b_malawi_merged/model-00001-of-00006.safetensors
# Loading model file Llama-2-13b_malawi_merged/model-00002-of-00006.safetensors
# Loading model file Llama-2-13b_malawi_merged/model-00003-of-00006.safetensors
# Loading model file Llama-2-13b_malawi_merged/model-00004-of-00006.safetensors
# Loading model file Llama-2-13b_malawi_merged/model-00005-of-00006.safetensors
# Loading model file Llama-2-13b_malawi_merged/model-00006-of-00006.safetensors
# params = Params(n_vocab=32000, n_embd=5120, n_layer=40, n_ctx=4096, n_ff=13824, n_head=40, n_head_kv=40, n_experts=None, n_experts_used=None, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyQ8_0: 7>, path_model=PosixPath('Llama-2-13b_malawi_merged'))
# ...

# %%
from huggingface_hub import HfApi
api = HfApi()
model_id = "Jayem-11/Llama-2-13b_malawi_merged_q8.gguf"
api.create_repo(model_id, exist_ok=True, repo_type="model")
api.upload_file(
    repo_id=model_id,
    path_or_fileobj="Llama-2-13b_malawi_merged.gguf",
    path_in_repo="Llama-2-13b_malawi_merged.gguf"
)
# Out:
# Llama-2-13b_malawi_merged.gguf:   0%|          | 0.00/13.8G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Jayem-11/Llama-2-13b_malawi_merged_q8.gguf/commit/c75240e9d6ea6c718fee64875622e51b750c1245', commit_message='Upload Llama-2-13b_malawi_merged.gguf with huggingface_hub', commit_description='', oid='c75240e9d6ea6c718fee64875622e51b750c1245', pr_url=None, pr_revision=None, pr_num=None)
